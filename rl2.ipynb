# %%
from QL import QLearningAgent

import traci 
import pickle 
import numpy as np 
import matplotlib.pyplot as plt
import random
from collections import defaultdict
from datetime import datetime
import pytz

sumo_exe = r"C:\Program Files (x86)\Eclipse\Sumo\bin\sumo.exe"
sumo_cfg = r"C:\Users\OMEN\Desktop\jun1\jun1.sumocfg"

episode = 1000
max_step = 1000
alpha = 0.05
gamma = 0.92

max_green = 30
min_green = 5
max_red = 3

n=900
e = 1
e_min = 0.05
e_decay = (0.05)**(1/n)
green_ph = [0,2,4,6]
red_ph = [1,3,5,7]
total_ph = 8
last_switch_step = 0

state_size = 5
action_size = 4

agent = QLearningAgent(state_size=state_size,action_size=action_size,alpha=alpha,gamma=gamma,epsilon=e,epsilon_decay=e_decay,epsilon_min=e_min)

tls_id = "cluster_26785788_26785789_26785790_26785791_4286289674_4286289675_4286289676_4286289679"

APPROACH_A = ['429488376#0_0', '429488376#0_1', '429488376#0_2', '429488376#0_3']
APPROACH_B = ['429488375#0_0', '429488375#0_1', '429488375#0_2']
APPROACH_C = ['328440060#1_0', '328440060#1_1', '328440060#1_2', '328440060#1_3']
APPROACH_D = ['338690994#0_0', '338690994#0_1', '338690994#0_2' , '338690994#0_3']

def queueOfSubLane(subLaneNo):
    return (traci.lane.getLastStepHaltingNumber(subLaneNo))
    
def maxQueueLength(laneList):
    a=[]
    for lane in laneList:
       a.append(queueOfSubLane(lane))
    return max(a)

def get_state(tls_id):
    A = maxQueueLength(APPROACH_A)
    B = maxQueueLength(APPROACH_B)
    C = maxQueueLength(APPROACH_C)
    D = maxQueueLength(APPROACH_D)
    L = traci.trafficlight.getPhase(tls_id)
    return (A, B, C, D, L)

def get_reward(state):
    A, B, C, D, _ = state
    return -(A*A + B*B + C*C + D*D)


def NextPhase(action,phase):
    if action == 1:
        return (phase + 2) % total_ph
    elif action == 2:
        return (phase + 4) % total_ph
    elif action == 3:
        return (phase + 6) % total_ph
    return phase
    
def YPhase(phase):
    return (phase + 1) % total_ph

    
def is_G(phase):
    return phase in green_ph

def current_phase(tls_id): 
    return traci.trafficlight.getPhase(tls_id)

def mustSwitch(phase,duration):
    if (phase in green_ph and duration >= max_green):
        return True
    elif (phase in red_ph and duration >= max_red):
        return True
    return False
    
def canRLAct(phase,duration):
    if (phase in green_ph and (duration >= min_green) and (duration < max_green )):
        return True
    return False

queue_history =[]
ep_history = []
reward_history = []
all_states = set()

for ep in range(1, episode + 1):
    ep_start_time = datetime.now(pytz.timezone("Asia/Kolkata")).strftime("%Y-%m-%d %H:%M:%S")
    ep_history.append(ep)

    traci.start([sumo_exe,"-c", sumo_cfg,"--no-step-log","--quit-on-end"])
    total_ph = len(traci.trafficlight.getAllProgramLogics(tls_id)[0].phases)
    phase_prev = traci.trafficlight.getPhase(tls_id)

    ep_reward = 0
    ep_states = set()    
    new_states = set()  
    total_ep_queue = 0
    
    max_q_change = 0
    step =0
    done = False
    while step < max_step:
        switch = False
        if(step == max_step-1):
            done = True

        discounted_reward = 0
        old_state = get_state(tls_id)
        action = agent.choose_action(old_state)
        phase = current_phase(tls_id)
        duration = traci.trafficlight.getSpentDuration(tls_id)
        total_ep_queue+= sum(old_state[:4])

        if(mustSwitch(phase,duration)):
            if phase in green_ph:
                if(action == 0 ):
                    action =  random.randint(1, 3)
                traci.trafficlight.setPhase(tls_id, (phase+1)%total_ph)
                traci.trafficlight.setPhaseDuration(tls_id, 3)
                for i in range(0,3):
                    traci.simulationStep()
                    switch = True
                    di_state = get_state(tls_id)
                    ep_reward+= get_reward(di_state)
                    total_ep_queue+= sum(di_state[:4])
                    discounted_reward+= get_reward(di_state) * (gamma ** i)
                step = step + 3 
                nextPhase = NextPhase(action,phase)
                traci.trafficlight.setPhase(tls_id,nextPhase)
                traci.trafficlight.setPhaseDuration(tls_id, 31)

            elif phase in red_ph:
                action = 1
                traci.trafficlight.setPhase(tls_id, (phase+1)%total_ph)
            
            phase = current_phase(tls_id)
            duration = traci.trafficlight.getSpentDuration(tls_id)

            if(phase in green_ph):
                traci.trafficlight.setPhaseDuration(tls_id, 31)
            else:
                traci.trafficlight.setPhaseDuration(tls_id, 3)

        elif(canRLAct(phase,duration)):
            if(action == 0):
                traci.trafficlight.setPhase(tls_id, phase)
                traci.trafficlight.setPhaseDuration(tls_id, 31)
            else:
                traci.trafficlight.setPhase(tls_id, (phase+1)%total_ph)
                traci.trafficlight.setPhaseDuration(tls_id, 3)
                for i in range(0,3):
                    switch = True
                    traci.simulationStep()
                    di_state = get_state(tls_id)
                    ep_reward+= get_reward(di_state)
                    total_ep_queue+= sum(di_state[:4])
                    discounted_reward+= get_reward(di_state) * (gamma ** i)
                step = step + 3 
                nextPhase = NextPhase(action,phase)
                traci.trafficlight.setPhase(tls_id,nextPhase)
                traci.trafficlight.setPhaseDuration(tls_id, 31)

        traci.simulationStep()
        step += 1

        phase_curr = traci.trafficlight.getPhase(tls_id)
        new_state = get_state(tls_id)
        reward = get_reward(new_state)
        ep_reward+=reward
         
        if(switch == False): 
           delta= agent.update( state=old_state, action=action, reward=reward, next_state=new_state, done=done, power=1)
        else:
            discounted_reward += reward * (gamma ** 3)
            delta = agent.update( state=old_state, action=action, reward=discounted_reward, next_state=new_state, done=done, power=4)

        if delta > max_q_change:
            max_q_change = delta

        ep_states.add(old_state)
        if old_state not in all_states:
            new_states.add(old_state)
            all_states.add(old_state)
        
    traci.close()
    agent.decay_epsilon()
    reward_history.append(ep_reward)
    queue_history.append(total_ep_queue)
    if ep % 10 == 0:
        with open("rl_model_2.pkl", "wb") as f:
            pickle.dump(agent.q_table, f) 
            
    print( f"Episode {ep:03d}/{episode} | "f"StartTime {ep_start_time} | "f"MaxQChange {max_q_change:.6f} | "f"QueueLength {total_ep_queue} | "f"Reward {ep_reward:12.2f} | "f"Epsilon {agent.epsilon:.3f} | "f"EpStates {len(ep_states):4d} | "f"NewStates {len(new_states):4d} | "f"TotalStates {len(all_states):5d}")
     
print("\nTraining finished")
print(f"Total learned states: {len(all_states)}")        
plt.figure(figsize=(10, 6))
plt.plot(ep_history, reward_history, marker='o', linestyle='-', label="Reward in each ep")
plt.xlabel("ep number")
plt.ylabel("reward at each ep")
plt.title("RL Training: Reward over Steps")
plt.legend()
plt.grid(True) 
plt.show()


plt.figure(figsize=(10, 6))
plt.plot(ep_history, queue_history, marker='o', linestyle='-', label="Total Queue Length")
plt.xlabel("Simulation Ep")
plt.ylabel("Total Queue Length")
plt.title("RL Training: Queue Length over Ep")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Episode 001/1000 | StartTime 2026-03-19 17:06:54 | MaxQChange 13.371414 | QueueLength 6940 | Reward    -30748.00 | Epsilon 0.997 | EpStates  223 | NewStates  223 | TotalStates   223
# Episode 002/1000 | StartTime 2026-03-19 17:06:59 | MaxQChange 14.547479 | QueueLength 8252 | Reward    -40799.00 | Epsilon 0.993 | EpStates  198 | NewStates   85 | TotalStates   308
# Episode 003/1000 | StartTime 2026-03-19 17:07:03 | MaxQChange 13.709040 | QueueLength 7746 | Reward    -36741.00 | Epsilon 0.990 | EpStates  217 | NewStates   64 | TotalStates   372
# Episode 004/1000 | StartTime 2026-03-19 17:07:07 | MaxQChange 14.909956 | QueueLength 7472 | Reward    -34032.00 | Epsilon 0.987 | EpStates  230 | NewStates   62 | TotalStates   434
# Episode 005/1000 | StartTime 2026-03-19 17:07:12 | MaxQChange 16.634609 | QueueLength 7997 | Reward    -38882.00 | Epsilon 0.983 | EpStates  234 | NewStates   48 | TotalStates   482
# Episode 006/1000 | StartTime 2026-03-19 17:07:16 | MaxQChange 16.487598 | QueueLength 7742 | Reward    -36859.00 | Epsilon 0.980 | EpStates  202 | NewStates   15 | TotalStates   497
# Episode 007/1000 | StartTime 2026-03-19 17:07:21 | MaxQChange 16.852542 | QueueLength 7467 | Reward    -35195.00 | Epsilon 0.977 | EpStates  220 | NewStates   28 | TotalStates   525
# Episode 008/1000 | StartTime 2026-03-19 17:07:25 | MaxQChange 18.224295 | QueueLength 8335 | Reward    -41612.00 | Epsilon 0.974 | EpStates  191 | NewStates   21 | TotalStates   546
# Episode 009/1000 | StartTime 2026-03-19 17:07:30 | MaxQChange 17.898427 | QueueLength 7671 | Reward    -37186.00 | Epsilon 0.970 | EpStates  238 | NewStates   43 | TotalStates   589
# Episode 010/1000 | StartTime 2026-03-19 17:07:34 | MaxQChange 19.110091 | QueueLength 7729 | Reward    -36275.00 | Epsilon 0.967 | EpStates  236 | NewStates   41 | TotalStates   630
# Episode 011/1000 | StartTime 2026-03-19 17:07:39 | MaxQChange 18.656932 | QueueLength 7927 | Reward    -38517.00 | Epsilon 0.964 | EpStates  199 | NewStates   12 | TotalStates   642
# Episode 012/1000 | StartTime 2026-03-19 17:07:43 | MaxQChange 17.280478 | QueueLength 7249 | Reward    -33141.00 | Epsilon 0.961 | EpStates  242 | NewStates   18 | TotalStates   660
# Episode 013/1000 | StartTime 2026-03-19 17:07:47 | MaxQChange 16.893802 | QueueLength 7246 | Reward    -32813.00 | Epsilon 0.958 | EpStates  251 | NewStates   38 | TotalStates   698
# Episode 014/1000 | StartTime 2026-03-19 17:07:51 | MaxQChange 19.434592 | QueueLength 7348 | Reward    -34737.00 | Epsilon 0.954 | EpStates  218 | NewStates    9 | TotalStates   707
# Episode 015/1000 | StartTime 2026-03-19 17:07:56 | MaxQChange 19.094963 | QueueLength 7363 | Reward    -32161.00 | Epsilon 0.951 | EpStates  226 | NewStates   25 | TotalStates   732
# Episode 016/1000 | StartTime 2026-03-19 17:08:00 | MaxQChange 16.504845 | QueueLength 7124 | Reward    -30753.00 | Epsilon 0.948 | EpStates  209 | NewStates    6 | TotalStates   738
# Episode 017/1000 | StartTime 2026-03-19 17:08:04 | MaxQChange 20.091067 | QueueLength 7175 | Reward    -31860.00 | Epsilon 0.945 | EpStates  208 | NewStates    5 | TotalStates   743
# Episode 018/1000 | StartTime 2026-03-19 17:08:09 | MaxQChange 16.974790 | QueueLength 7739 | Reward    -37396.00 | Epsilon 0.942 | EpStates  220 | NewStates    8 | TotalStates   751
# Episode 019/1000 | StartTime 2026-03-19 17:08:13 | MaxQChange 20.104406 | QueueLength 7253 | Reward    -32147.00 | Epsilon 0.939 | EpStates  228 | NewStates    7 | TotalStates   758
# Episode 020/1000 | StartTime 2026-03-19 17:08:17 | MaxQChange 16.882586 | QueueLength 7535 | Reward    -33694.00 | Epsilon 0.936 | EpStates  258 | NewStates   39 | TotalStates   797
# Episode 021/1000 | StartTime 2026-03-19 17:08:22 | MaxQChange 19.556159 | QueueLength 8000 | Reward    -40474.00 | Epsilon 0.932 | EpStates  213 | NewStates    3 | TotalStates   800
# Episode 022/1000 | StartTime 2026-03-19 17:08:26 | MaxQChange 22.336211 | QueueLength 8315 | Reward    -42698.00 | Epsilon 0.929 | EpStates  186 | NewStates    5 | TotalStates   805
# Episode 023/1000 | StartTime 2026-03-19 17:08:30 | MaxQChange 21.848992 | QueueLength 7705 | Reward    -36973.00 | Epsilon 0.926 | EpStates  212 | NewStates   12 | TotalStates   817
# Episode 024/1000 | StartTime 2026-03-19 17:08:35 | MaxQChange 19.646033 | QueueLength 7632 | Reward    -36125.00 | Epsilon 0.923 | EpStates  216 | NewStates   10 | TotalStates   827
# Episode 025/1000 | StartTime 2026-03-19 17:08:39 | MaxQChange 18.188593 | QueueLength 7677 | Reward    -36381.00 | Epsilon 0.920 | EpStates  225 | NewStates    6 | TotalStates   833
# Episode 026/1000 | StartTime 2026-03-19 17:08:44 | MaxQChange 13.128836 | QueueLength 7266 | Reward    -33991.00 | Epsilon 0.917 | EpStates  202 | NewStates    8 | TotalStates   841
# Episode 027/1000 | StartTime 2026-03-19 17:08:48 | MaxQChange 19.310348 | QueueLength 8161 | Reward    -39591.00 | Epsilon 0.914 | EpStates  221 | NewStates   17 | TotalStates   858
# Episode 028/1000 | StartTime 2026-03-19 17:08:52 | MaxQChange 18.249773 | QueueLength 7222 | Reward    -33463.00 | Epsilon 0.911 | EpStates  246 | NewStates    9 | TotalStates   867
# Episode 029/1000 | StartTime 2026-03-19 17:08:56 | MaxQChange 19.078715 | QueueLength 7501 | Reward    -34688.00 | Epsilon 0.908 | EpStates  231 | NewStates   25 | TotalStates   892
# Episode 045/1000 | StartTime 2026-03-19 17:10:06 | MaxQChange 19.965716 | QueueLength 7629 | Reward    -35378.00 | Epsilon 0.861 | EpStates  221 | NewStates    8 | TotalStates  1031
# Episode 046/1000 | StartTime 2026-03-19 17:10:10 | MaxQChange 19.251938 | QueueLength 7079 | Reward    -31719.00 | Epsilon 0.858 | EpStates  233 | NewStates    3 | TotalStates  1034
# Episode 047/1000 | StartTime 2026-03-19 17:10:15 | MaxQChange 16.200310 | QueueLength 6311 | Reward    -24999.00 | Epsilon 0.855 | EpStates  235 | NewStates   15 | TotalStates  1049
# Episode 048/1000 | StartTime 2026-03-19 17:10:19 | MaxQChange 22.126413 | QueueLength 7918 | Reward    -37197.00 | Epsilon 0.852 | EpStates  258 | NewStates   23 | TotalStates  1072
# Episode 049/1000 | StartTime 2026-03-19 17:10:23 | MaxQChange 22.554809 | QueueLength 7701 | Reward    -37365.00 | Epsilon 0.850 | EpStates  196 | NewStates    0 | TotalStates  1072
# Episode 050/1000 | StartTime 2026-03-19 17:10:28 | MaxQChange 24.482932 | QueueLength 8279 | Reward    -42088.00 | Epsilon 0.847 | EpStates  207 | NewStates    6 | TotalStates  1078
# Episode 051/1000 | StartTime 2026-03-19 17:10:32 | MaxQChange 17.138254 | QueueLength 7902 | Reward    -36693.00 | Epsilon 0.844 | EpStates  239 | NewStates    5 | TotalStates  1083
# Episode 052/1000 | StartTime 2026-03-19 17:10:36 | MaxQChange 20.909178 | QueueLength 7147 | Reward    -32687.00 | Epsilon 0.841 | EpStates  195 | NewStates    2 | TotalStates  1085
# Episode 053/1000 | StartTime 2026-03-19 17:10:41 | MaxQChange 19.106055 | QueueLength 6921 | Reward    -32233.00 | Epsilon 0.838 | EpStates  229 | NewStates    0 | TotalStates  1085
# Episode 054/1000 | StartTime 2026-03-19 17:10:45 | MaxQChange 18.690291 | QueueLength 7831 | Reward    -37140.00 | Epsilon 0.835 | EpStates  239 | NewStates    1 | TotalStates  1086
# Episode 055/1000 | StartTime 2026-03-19 17:10:49 | MaxQChange 21.714814 | QueueLength 7944 | Reward    -37586.00 | Epsilon 0.833 | EpStates  209 | NewStates    0 | TotalStates  1086
# Episode 056/1000 | StartTime 2026-03-19 17:10:54 | MaxQChange 19.504370 | QueueLength 7659 | Reward    -37453.00 | Epsilon 0.830 | EpStates  218 | NewStates    1 | TotalStates  1087
# Episode 057/1000 | StartTime 2026-03-19 17:10:58 | MaxQChange 20.961873 | QueueLength 7665 | Reward    -35342.00 | Epsilon 0.827 | EpStates  269 | NewStates    8 | TotalStates  1095
# Episode 058/1000 | StartTime 2026-03-19 17:11:03 | MaxQChange 20.644545 | QueueLength 6908 | Reward    -30595.00 | Epsilon 0.824 | EpStates  249 | NewStates    0 | TotalStates  1095
# Episode 059/1000 | StartTime 2026-03-19 17:11:07 | MaxQChange 15.808535 | QueueLength 7360 | Reward    -33549.00 | Epsilon 0.822 | EpStates  248 | NewStates    5 | TotalStates  1100
# Episode 060/1000 | StartTime 2026-03-19 17:11:11 | MaxQChange 14.077847 | QueueLength 7434 | Reward    -36121.00 | Epsilon 0.819 | EpStates  195 | NewStates    0 | TotalStates  1100
# Episode 061/1000 | StartTime 2026-03-19 17:11:16 | MaxQChange 16.251420 | QueueLength 7897 | Reward    -36544.00 | Epsilon 0.816 | EpStates  271 | NewStates   18 | TotalStates  1118
# Episode 062/1000 | StartTime 2026-03-19 17:11:20 | MaxQChange 23.219065 | QueueLength 7341 | Reward    -32405.00 | Epsilon 0.814 | EpStates  267 | NewStates    7 | TotalStates  1125
# Episode 063/1000 | StartTime 2026-03-19 17:11:24 | MaxQChange 10.224179 | QueueLength 5516 | Reward    -20404.00 | Epsilon 0.811 | EpStates  214 | NewStates   18 | TotalStates  1143
# Episode 064/1000 | StartTime 2026-03-19 17:11:29 | MaxQChange 21.809358 | QueueLength 7766 | Reward    -36095.00 | Epsilon 0.808 | EpStates  239 | NewStates    3 | TotalStates  1146
# Episode 065/1000 | StartTime 2026-03-19 17:11:33 | MaxQChange 22.815342 | QueueLength 8155 | Reward    -38556.00 | Epsilon 0.805 | EpStates  289 | NewStates   21 | TotalStates  1167
# Episode 066/1000 | StartTime 2026-03-19 17:11:38 | MaxQChange 18.328334 | QueueLength 7248 | Reward    -34374.00 | Epsilon 0.803 | EpStates  212 | NewStates    6 | TotalStates  1173
# Episode 067/1000 | StartTime 2026-03-19 17:11:42 | MaxQChange 21.025874 | QueueLength 7743 | Reward    -37561.00 | Epsilon 0.800 | EpStates  189 | NewStates    0 | TotalStates  1173
# Episode 068/1000 | StartTime 2026-03-19 17:11:46 | MaxQChange 21.964890 | QueueLength 7991 | Reward    -38402.00 | Epsilon 0.797 | EpStates  241 | NewStates    4 | TotalStates  1177
# Episode 069/1000 | StartTime 2026-03-19 17:11:51 | MaxQChange 20.635152 | QueueLength 7977 | Reward    -39331.00 | Epsilon 0.795 | EpStates  210 | NewStates    4 | TotalStates  1181
# Episode 070/1000 | StartTime 2026-03-19 17:11:55 | MaxQChange 22.026610 | QueueLength 7966 | Reward    -39080.00 | Epsilon 0.792 | EpStates  221 | NewStates    2 | TotalStates  1183
# Episode 071/1000 | StartTime 2026-03-19 17:12:00 | MaxQChange 27.102452 | QueueLength 7834 | Reward    -37926.00 | Epsilon 0.790 | EpStates  203 | NewStates    2 | TotalStates  1185
# Episode 072/1000 | StartTime 2026-03-19 17:12:04 | MaxQChange 21.294613 | QueueLength 7536 | Reward    -35066.00 | Epsilon 0.787 | EpStates  246 | NewStates    1 | TotalStates  1186
# Episode 073/1000 | StartTime 2026-03-19 17:12:09 | MaxQChange 20.414450 | QueueLength 7722 | Reward    -38144.00 | Epsilon 0.784 | EpStates  211 | NewStates    0 | TotalStates  1186
# Episode 074/1000 | StartTime 2026-03-19 17:12:13 | MaxQChange 20.707356 | QueueLength 7616 | Reward    -36259.00 | Epsilon 0.782 | EpStates  220 | NewStates    0 | TotalStates  1186
# Episode 075/1000 | StartTime 2026-03-19 17:12:18 | MaxQChange 17.140988 | QueueLength 7335 | Reward    -32228.00 | Epsilon 0.779 | EpStates  273 | NewStates    9 | TotalStates  1195
# Episode 076/1000 | StartTime 2026-03-19 17:12:22 | MaxQChange 19.507545 | QueueLength 7541 | Reward    -35752.00 | Epsilon 0.776 | EpStates  245 | NewStates    4 | TotalStates  1199
# Episode 077/1000 | StartTime 2026-03-19 17:12:26 | MaxQChange 11.185595 | QueueLength 6502 | Reward    -26580.00 | Epsilon 0.774 | EpStates  229 | NewStates    0 | TotalStates  1199
# Episode 078/1000 | StartTime 2026-03-19 17:12:31 | MaxQChange 19.234195 | QueueLength 7107 | Reward    -32000.00 | Epsilon 0.771 | EpStates  248 | NewStates    7 | TotalStates  1206
# Episode 079/1000 | StartTime 2026-03-19 17:12:35 | MaxQChange 18.905879 | QueueLength 7074 | Reward    -30238.00 | Epsilon 0.769 | EpStates  242 | NewStates    1 | TotalStates  1207
# Episode 080/1000 | StartTime 2026-03-19 17:12:40 | MaxQChange 17.146033 | QueueLength 7343 | Reward    -32093.00 | Epsilon 0.766 | EpStates  306 | NewStates   17 | TotalStates  1224
# Episode 081/1000 | StartTime 2026-03-19 17:12:44 | MaxQChange 19.090233 | QueueLength 6892 | Reward    -30082.00 | Epsilon 0.764 | EpStates  257 | NewStates    1 | TotalStates  1225
# Episode 082/1000 | StartTime 2026-03-19 17:12:48 | MaxQChange 19.565965 | QueueLength 7427 | Reward    -31998.00 | Epsilon 0.761 | EpStates  260 | NewStates    5 | TotalStates  1230
# Episode 083/1000 | StartTime 2026-03-19 17:12:53 | MaxQChange 18.870802 | QueueLength 6934 | Reward    -29987.00 | Epsilon 0.759 | EpStates  258 | NewStates    4 | TotalStates  1234
# Episode 084/1000 | StartTime 2026-03-19 17:12:57 | MaxQChange 13.863545 | QueueLength 6854 | Reward    -30734.00 | Epsilon 0.756 | EpStates  264 | NewStates    5 | TotalStates  1239
# Episode 085/1000 | StartTime 2026-03-19 17:13:02 | MaxQChange 14.896065 | QueueLength 7594 | Reward    -35696.00 | Epsilon 0.754 | EpStates  228 | NewStates    0 | TotalStates  1239
# Episode 086/1000 | StartTime 2026-03-19 17:13:06 | MaxQChange 20.667823 | QueueLength 6990 | Reward    -30481.00 | Epsilon 0.751 | EpStates  237 | NewStates    0 | TotalStates  1239
# Episode 087/1000 | StartTime 2026-03-19 17:13:10 | MaxQChange 19.800674 | QueueLength 6843 | Reward    -31501.00 | Epsilon 0.749 | EpStates  227 | NewStates    4 | TotalStates  1243
# Episode 088/1000 | StartTime 2026-03-19 17:13:15 | MaxQChange 17.039563 | QueueLength 7392 | Reward    -34248.00 | Epsilon 0.746 | EpStates  264 | NewStates   11 | TotalStates  1254
# Episode 089/1000 | StartTime 2026-03-19 17:13:19 | MaxQChange 21.755663 | QueueLength 6867 | Reward    -29629.00 | Epsilon 0.744 | EpStates  299 | NewStates    2 | TotalStates  1256
# Episode 090/1000 | StartTime 2026-03-19 17:13:24 | MaxQChange 23.964500 | QueueLength 7488 | Reward    -33731.00 | Epsilon 0.741 | EpStates  268 | NewStates   11 | TotalStates  1267
# Episode 091/1000 | StartTime 2026-03-19 17:13:28 | MaxQChange 20.328427 | QueueLength 6699 | Reward    -29347.00 | Epsilon 0.739 | EpStates  249 | NewStates    8 | TotalStates  1275
# Episode 092/1000 | StartTime 2026-03-19 17:13:33 | MaxQChange 24.823362 | QueueLength 6259 | Reward    -25756.00 | Epsilon 0.736 | EpStates  250 | NewStates    0 | TotalStates  1275
# Episode 093/1000 | StartTime 2026-03-19 17:13:37 | MaxQChange 19.228589 | QueueLength 7089 | Reward    -30804.00 | Epsilon 0.734 | EpStates  263 | NewStates    4 | TotalStates  1279
# Episode 094/1000 | StartTime 2026-03-19 17:13:41 | MaxQChange 19.824635 | QueueLength 7715 | Reward    -37324.00 | Epsilon 0.731 | EpStates  190 | NewStates    0 | TotalStates  1279
# Episode 095/1000 | StartTime 2026-03-19 17:13:46 | MaxQChange 15.083863 | QueueLength 6331 | Reward    -27304.00 | Epsilon 0.729 | EpStates  226 | NewStates    2 | TotalStates  1281
# Episode 096/1000 | StartTime 2026-03-19 17:13:50 | MaxQChange 18.837715 | QueueLength 7069 | Reward    -32823.00 | Epsilon 0.726 | EpStates  215 | NewStates    1 | TotalStates  1282
# Episode 097/1000 | StartTime 2026-03-19 17:13:55 | MaxQChange 23.558259 | QueueLength 7680 | Reward    -37202.00 | Epsilon 0.724 | EpStates  211 | NewStates    0 | TotalStates  1282
# Episode 098/1000 | StartTime 2026-03-19 17:13:59 | MaxQChange 22.689851 | QueueLength 7856 | Reward    -36989.00 | Epsilon 0.722 | EpStates  216 | NewStates    1 | TotalStates  1283
# Episode 099/1000 | StartTime 2026-03-19 17:14:03 | MaxQChange 20.673204 | QueueLength 7646 | Reward    -35837.00 | Epsilon 0.719 | EpStates  230 | NewStates    4 | TotalStates  1287
# Episode 100/1000 | StartTime 2026-03-19 17:14:08 | MaxQChange 19.914971 | QueueLength 7675 | Reward    -34396.00 | Epsilon 0.717 | EpStates  285 | NewStates   24 | TotalStates  1311
# Episode 101/1000 | StartTime 2026-03-19 17:14:12 | MaxQChange 18.118633 | QueueLength 8322 | Reward    -41097.00 | Epsilon 0.714 | EpStates  227 | NewStates    4 | TotalStates  1315
# Episode 102/1000 | StartTime 2026-03-19 17:14:16 | MaxQChange 24.736255 | QueueLength 7339 | Reward    -33245.00 | Epsilon 0.712 | EpStates  246 | NewStates    4 | TotalStates  1319
# Episode 103/1000 | StartTime 2026-03-19 17:14:21 | MaxQChange 20.382228 | QueueLength 6691 | Reward    -26918.00 | Epsilon 0.710 | EpStates  269 | NewStates    9 | TotalStates  1328
# Episode 104/1000 | StartTime 2026-03-19 17:14:25 | MaxQChange 21.580492 | QueueLength 6687 | Reward    -28224.00 | Epsilon 0.707 | EpStates  259 | NewStates    7 | TotalStates  1335
# Episode 105/1000 | StartTime 2026-03-19 17:14:29 | MaxQChange 20.127550 | QueueLength 8032 | Reward    -37639.00 | Epsilon 0.705 | EpStates  240 | NewStates    9 | TotalStates  1344
# Episode 106/1000 | StartTime 2026-03-19 17:14:34 | MaxQChange 17.319303 | QueueLength 7325 | Reward    -33383.00 | Epsilon 0.703 | EpStates  243 | NewStates    4 | TotalStates  1348
# Episode 137/1000 | StartTime 2026-03-19 17:16:49 | MaxQChange 17.624273 | QueueLength 7355 | Reward    -32662.00 | Epsilon 0.634 | EpStates  287 | NewStates    5 | TotalStates  1469
# Episode 138/1000 | StartTime 2026-03-19 17:16:53 | MaxQChange 19.717301 | QueueLength 5783 | Reward    -22123.00 | Epsilon 0.632 | EpStates  235 | NewStates    0 | TotalStates  1469
# Episode 139/1000 | StartTime 2026-03-19 17:16:58 | MaxQChange 17.779580 | QueueLength 7305 | Reward    -32910.00 | Epsilon 0.630 | EpStates  302 | NewStates    2 | TotalStates  1471
# Episode 140/1000 | StartTime 2026-03-19 17:17:02 | MaxQChange 19.768230 | QueueLength 7612 | Reward    -35130.00 | Epsilon 0.628 | EpStates  251 | NewStates    1 | TotalStates  1472
# Episode 141/1000 | StartTime 2026-03-19 17:17:07 | MaxQChange 17.879027 | QueueLength 7429 | Reward    -34054.00 | Epsilon 0.625 | EpStates  264 | NewStates    4 | TotalStates  1476
# Episode 142/1000 | StartTime 2026-03-19 17:17:11 | MaxQChange 17.577740 | QueueLength 7259 | Reward    -31854.00 | Epsilon 0.623 | EpStates  236 | NewStates    1 | TotalStates  1477
# Episode 143/1000 | StartTime 2026-03-19 17:17:15 | MaxQChange 20.700594 | QueueLength 7392 | Reward    -34554.00 | Epsilon 0.621 | EpStates  244 | NewStates    0 | TotalStates  1477
# Episode 144/1000 | StartTime 2026-03-19 17:17:20 | MaxQChange 20.248638 | QueueLength 8059 | Reward    -39334.00 | Epsilon 0.619 | EpStates  229 | NewStates    0 | TotalStates  1477
# Episode 145/1000 | StartTime 2026-03-19 17:17:24 | MaxQChange 20.514290 | QueueLength 7088 | Reward    -30713.00 | Epsilon 0.617 | EpStates  249 | NewStates    4 | TotalStates  1481
# Episode 146/1000 | StartTime 2026-03-19 17:17:29 | MaxQChange 18.832190 | QueueLength 7322 | Reward    -33275.00 | Epsilon 0.615 | EpStates  266 | NewStates    0 | TotalStates  1481
# Episode 147/1000 | StartTime 2026-03-19 17:17:33 | MaxQChange 18.949086 | QueueLength 7322 | Reward    -33389.00 | Epsilon 0.613 | EpStates  239 | NewStates    2 | TotalStates  1483
# Episode 148/1000 | StartTime 2026-03-19 17:17:38 | MaxQChange 21.401142 | QueueLength 7338 | Reward    -31988.00 | Epsilon 0.611 | EpStates  267 | NewStates    0 | TotalStates  1483
# Episode 149/1000 | StartTime 2026-03-19 17:17:42 | MaxQChange 25.470401 | QueueLength 6841 | Reward    -30183.00 | Epsilon 0.609 | EpStates  241 | NewStates    3 | TotalStates  1486
# Episode 150/1000 | StartTime 2026-03-19 17:17:46 | MaxQChange 17.117751 | QueueLength 7648 | Reward    -33550.00 | Epsilon 0.607 | EpStates  312 | NewStates   11 | TotalStates  1497
# Episode 151/1000 | StartTime 2026-03-19 17:17:51 | MaxQChange 19.749374 | QueueLength 7126 | Reward    -31061.00 | Epsilon 0.605 | EpStates  290 | NewStates    1 | TotalStates  1498
# Episode 152/1000 | StartTime 2026-03-19 17:17:55 | MaxQChange 22.552570 | QueueLength 7088 | Reward    -31208.00 | Epsilon 0.603 | EpStates  289 | NewStates    2 | TotalStates  1500
# Episode 153/1000 | StartTime 2026-03-19 17:18:00 | MaxQChange 24.400748 | QueueLength 7464 | Reward    -31339.00 | Epsilon 0.601 | EpStates  318 | NewStates    8 | TotalStates  1508
# Episode 154/1000 | StartTime 2026-03-19 17:18:04 | MaxQChange 16.750687 | QueueLength 7179 | Reward    -32890.00 | Epsilon 0.599 | EpStates  260 | NewStates    5 | TotalStates  1513
# Episode 155/1000 | StartTime 2026-03-19 17:18:08 | MaxQChange 19.237381 | QueueLength 7371 | Reward    -34158.00 | Epsilon 0.597 | EpStates  246 | NewStates    1 | TotalStates  1514
# Episode 156/1000 | StartTime 2026-03-19 17:18:13 | MaxQChange 20.545219 | QueueLength 7163 | Reward    -32092.00 | Epsilon 0.595 | EpStates  267 | NewStates    3 | TotalStates  1517
# Episode 157/1000 | StartTime 2026-03-19 17:18:17 | MaxQChange 8.643460 | QueueLength 5140 | Reward    -16188.00 | Epsilon 0.593 | EpStates  217 | NewStates    4 | TotalStates  1521
# Episode 158/1000 | StartTime 2026-03-19 17:18:22 | MaxQChange 21.890642 | QueueLength 6376 | Reward    -25896.00 | Epsilon 0.591 | EpStates  284 | NewStates    5 | TotalStates  1526
# Episode 159/1000 | StartTime 2026-03-19 17:18:26 | MaxQChange 17.449629 | QueueLength 5691 | Reward    -20812.00 | Epsilon 0.589 | EpStates  266 | NewStates   11 | TotalStates  1537
# Episode 160/1000 | StartTime 2026-03-19 17:18:31 | MaxQChange 18.272790 | QueueLength 5442 | Reward    -19223.00 | Epsilon 0.587 | EpStates  260 | NewStates    2 | TotalStates  1539
# Episode 161/1000 | StartTime 2026-03-19 17:18:35 | MaxQChange 14.044907 | QueueLength 6663 | Reward    -26213.00 | Epsilon 0.585 | EpStates  264 | NewStates    5 | TotalStates  1544
# Episode 162/1000 | StartTime 2026-03-19 17:18:40 | MaxQChange 19.839610 | QueueLength 7213 | Reward    -31377.00 | Epsilon 0.583 | EpStates  297 | NewStates    1 | TotalStates  1545
# Episode 163/1000 | StartTime 2026-03-19 17:18:44 | MaxQChange 13.764805 | QueueLength 6053 | Reward    -23258.00 | Epsilon 0.581 | EpStates  257 | NewStates    0 | TotalStates  1545
# Episode 164/1000 | StartTime 2026-03-19 17:18:48 | MaxQChange 14.809535 | QueueLength 6012 | Reward    -22215.00 | Epsilon 0.579 | EpStates  250 | NewStates    0 | TotalStates  1545
# Episode 165/1000 | StartTime 2026-03-19 17:18:53 | MaxQChange 24.265671 | QueueLength 7305 | Reward    -33878.00 | Epsilon 0.577 | EpStates  275 | NewStates    2 | TotalStates  1547
# Episode 166/1000 | StartTime 2026-03-19 17:18:57 | MaxQChange 20.174415 | QueueLength 7509 | Reward    -34868.00 | Epsilon 0.575 | EpStates  252 | NewStates    0 | TotalStates  1547
# Episode 167/1000 | StartTime 2026-03-19 17:19:01 | MaxQChange 18.875583 | QueueLength 7681 | Reward    -34236.00 | Epsilon 0.574 | EpStates  323 | NewStates   25 | TotalStates  1572
# Episode 199/1000 | StartTime 2026-03-19 17:21:20 | MaxQChange 19.803202 | QueueLength 7015 | Reward    -29172.00 | Epsilon 0.516 | EpStates  308 | NewStates    2 | TotalStates  1690
# Episode 200/1000 | StartTime 2026-03-19 17:21:24 | MaxQChange 19.959466 | QueueLength 6810 | Reward    -29677.00 | Epsilon 0.514 | EpStates  246 | NewStates    1 | TotalStates  1691
# Episode 201/1000 | StartTime 2026-03-19 17:21:28 | MaxQChange 20.530168 | QueueLength 6942 | Reward    -25712.00 | Epsilon 0.512 | EpStates  334 | NewStates    8 | TotalStates  1699
# Episode 202/1000 | StartTime 2026-03-19 17:21:33 | MaxQChange 24.098910 | QueueLength 6568 | Reward    -26165.00 | Epsilon 0.510 | EpStates  290 | NewStates    2 | TotalStates  1701
# Episode 203/1000 | StartTime 2026-03-19 17:21:37 | MaxQChange 21.641181 | QueueLength 7093 | Reward    -29475.00 | Epsilon 0.509 | EpStates  349 | NewStates    6 | TotalStates  1707
# Episode 204/1000 | StartTime 2026-03-19 17:21:41 | MaxQChange 10.023966 | QueueLength 4733 | Reward    -13903.00 | Epsilon 0.507 | EpStates  212 | NewStates    2 | TotalStates  1709
# Episode 205/1000 | StartTime 2026-03-19 17:21:45 | MaxQChange 18.638811 | QueueLength 6630 | Reward    -27836.00 | Epsilon 0.505 | EpStates  290 | NewStates    2 | TotalStates  1711
# Episode 206/1000 | StartTime 2026-03-19 17:21:50 | MaxQChange 18.558370 | QueueLength 6690 | Reward    -27453.00 | Epsilon 0.504 | EpStates  290 | NewStates    2 | TotalStates  1713
# Episode 207/1000 | StartTime 2026-03-19 17:21:54 | MaxQChange 12.882695 | QueueLength 5461 | Reward    -17931.00 | Epsilon 0.502 | EpStates  268 | NewStates    0 | TotalStates  1713
# Episode 208/1000 | StartTime 2026-03-19 17:21:58 | MaxQChange 18.896060 | QueueLength 5642 | Reward    -18911.00 | Epsilon 0.500 | EpStates  283 | NewStates    9 | TotalStates  1722
# Episode 209/1000 | StartTime 2026-03-19 17:22:03 | MaxQChange 19.036364 | QueueLength 6095 | Reward    -23760.00 | Epsilon 0.499 | EpStates  288 | NewStates    0 | TotalStates  1722
# Episode 210/1000 | StartTime 2026-03-19 17:22:07 | MaxQChange 17.550134 | QueueLength 5969 | Reward    -20575.00 | Epsilon 0.497 | EpStates  288 | NewStates   13 | TotalStates  1735
# Episode 211/1000 | StartTime 2026-03-19 17:22:11 | MaxQChange 16.629778 | QueueLength 6914 | Reward    -30743.00 | Epsilon 0.495 | EpStates  280 | NewStates    1 | TotalStates  1736
# Episode 212/1000 | StartTime 2026-03-19 17:22:15 | MaxQChange 20.572614 | QueueLength 6521 | Reward    -25595.00 | Epsilon 0.494 | EpStates  297 | NewStates    5 | TotalStates  1741
# Episode 213/1000 | StartTime 2026-03-19 17:22:20 | MaxQChange 17.169752 | QueueLength 6297 | Reward    -24096.00 | Epsilon 0.492 | EpStates  260 | NewStates    1 | TotalStates  1742
# Episode 214/1000 | StartTime 2026-03-19 17:22:24 | MaxQChange 20.122902 | QueueLength 6454 | Reward    -26208.00 | Epsilon 0.491 | EpStates  266 | NewStates    2 | TotalStates  1744
# Episode 215/1000 | StartTime 2026-03-19 17:22:28 | MaxQChange 16.013108 | QueueLength 6418 | Reward    -24261.00 | Epsilon 0.489 | EpStates  298 | NewStates    3 | TotalStates  1747
# Episode 216/1000 | StartTime 2026-03-19 17:22:32 | MaxQChange 24.801206 | QueueLength 6744 | Reward    -27618.00 | Epsilon 0.487 | EpStates  299 | NewStates    2 | TotalStates  1749
# Episode 217/1000 | StartTime 2026-03-19 17:22:37 | MaxQChange 9.725751 | QueueLength 5238 | Reward    -16597.00 | Epsilon 0.486 | EpStates  260 | NewStates    2 | TotalStates  1751
# Episode 218/1000 | StartTime 2026-03-19 17:22:41 | MaxQChange 17.846465 | QueueLength 7430 | Reward    -34423.00 | Epsilon 0.484 | EpStates  245 | NewStates    2 | TotalStates  1753
# Episode 219/1000 | StartTime 2026-03-19 17:22:45 | MaxQChange 21.598260 | QueueLength 5847 | Reward    -20152.00 | Epsilon 0.482 | EpStates  294 | NewStates    3 | TotalStates  1756
# Episode 220/1000 | StartTime 2026-03-19 17:22:49 | MaxQChange 21.117833 | QueueLength 6464 | Reward    -26429.00 | Epsilon 0.481 | EpStates  306 | NewStates    3 | TotalStates  1759
# Episode 221/1000 | StartTime 2026-03-19 17:22:54 | MaxQChange 9.608057 | QueueLength 4604 | Reward    -13378.00 | Epsilon 0.479 | EpStates  243 | NewStates    2 | TotalStates  1761
# Episode 222/1000 | StartTime 2026-03-19 17:22:58 | MaxQChange 20.153783 | QueueLength 7037 | Reward    -31164.00 | Epsilon 0.478 | EpStates  299 | NewStates    0 | TotalStates  1761
# Episode 223/1000 | StartTime 2026-03-19 17:23:02 | MaxQChange 21.323521 | QueueLength 7093 | Reward    -31117.00 | Epsilon 0.476 | EpStates  286 | NewStates    2 | TotalStates  1763
# Episode 224/1000 | StartTime 2026-03-19 17:23:07 | MaxQChange 17.988620 | QueueLength 5752 | Reward    -20606.00 | Epsilon 0.474 | EpStates  262 | NewStates    0 | TotalStates  1763
# Episode 225/1000 | StartTime 2026-03-19 17:23:11 | MaxQChange 18.384026 | QueueLength 5274 | Reward    -17599.00 | Epsilon 0.473 | EpStates  246 | NewStates    2 | TotalStates  1765
# Episode 226/1000 | StartTime 2026-03-19 17:23:15 | MaxQChange 19.482043 | QueueLength 5653 | Reward    -20514.00 | Epsilon 0.471 | EpStates  291 | NewStates    4 | TotalStates  1769
# Episode 227/1000 | StartTime 2026-03-19 17:23:19 | MaxQChange 18.727484 | QueueLength 6360 | Reward    -25047.00 | Epsilon 0.470 | EpStates  245 | NewStates    0 | TotalStates  1769
# Episode 228/1000 | StartTime 2026-03-19 17:23:24 | MaxQChange 21.362638 | QueueLength 6304 | Reward    -25407.00 | Epsilon 0.468 | EpStates  286 | NewStates    1 | TotalStates  1770
# Episode 229/1000 | StartTime 2026-03-19 17:23:28 | MaxQChange 18.398105 | QueueLength 6538 | Reward    -27992.00 | Epsilon 0.467 | EpStates  268 | NewStates    0 | TotalStates  1770
# Episode 260/1000 | StartTime 2026-03-19 17:25:40 | MaxQChange 18.311316 | QueueLength 6724 | Reward    -26777.00 | Epsilon 0.421 | EpStates  337 | NewStates    3 | TotalStates  1828
# Episode 261/1000 | StartTime 2026-03-19 17:25:45 | MaxQChange 10.361934 | QueueLength 5167 | Reward    -16610.00 | Epsilon 0.419 | EpStates  248 | NewStates    2 | TotalStates  1830
# Episode 262/1000 | StartTime 2026-03-19 17:25:49 | MaxQChange 10.668592 | QueueLength 5789 | Reward    -20002.00 | Epsilon 0.418 | EpStates  275 | NewStates    0 | TotalStates  1830
# Episode 263/1000 | StartTime 2026-03-19 17:25:53 | MaxQChange 24.097278 | QueueLength 4917 | Reward    -15642.00 | Epsilon 0.417 | EpStates  228 | NewStates    0 | TotalStates  1830
# ...
# Episode 913/1000 | StartTime 2026-03-19 18:08:14 | MaxQChange 5.229310 | QueueLength 2859 | Reward     -4697.00 | Epsilon 0.050 | EpStates  133 | NewStates    0 | TotalStates  2354
# Episode 914/1000 | StartTime 2026-03-19 18:08:18 | MaxQChange 4.874913 | QueueLength 3165 | Reward     -5804.00 | Epsilon 0.050 | EpStates  149 | NewStates    0 | TotalStates  2354
# Episode 915/1000 | StartTime 2026-03-19 18:08:22 | MaxQChange 3.435076 | QueueLength 2988 | Reward     -5115.00 | Epsilon 0.050 | EpStates  147 | NewStates    0 | TotalStates  2354
# Episode 916/1000 | StartTime 2026-03-19 18:08:26 | MaxQChange 4.893262 | QueueLength 2928 | Reward     -5035.00 | Epsilon 0.050 | EpStates  147 | NewStates    0 | TotalStates  2354
# Episode 917/1000 | StartTime 2026-03-19 18:08:30 | MaxQChange 5.137143 | QueueLength 3549 | Reward     -7281.00 | Epsilon 0.050 | EpStates  189 | NewStates    0 | TotalStates  2354
# Episode 918/1000 | StartTime 2026-03-19 18:08:34 | MaxQChange 11.893581 | QueueLength 2837 | Reward     -5475.00 | Epsilon 0.050 | EpStates  141 | NewStates    0 | TotalStates  2354
# Episode 919/1000 | StartTime 2026-03-19 18:08:38 | MaxQChange 6.201647 | QueueLength 3213 | Reward     -6148.00 | Epsilon 0.050 | EpStates  172 | NewStates    0 | TotalStates  2354
# Episode 920/1000 | StartTime 2026-03-19 18:08:43 | MaxQChange 6.332348 | QueueLength 3377 | Reward     -7003.00 | Epsilon 0.050 | EpStates  196 | NewStates    0 | TotalStates  2354
# Episode 921/1000 | StartTime 2026-03-19 18:08:47 | MaxQChange 4.039992 | QueueLength 2984 | Reward     -5515.00 | Epsilon 0.050 | EpStates  136 | NewStates    0 | TotalStates  2354
# Episode 922/1000 | StartTime 2026-03-19 18:08:51 | MaxQChange 5.017997 | QueueLength 2829 | Reward     -4968.00 | Epsilon 0.050 | EpStates  151 | NewStates    0 | TotalStates  2354
# Episode 923/1000 | StartTime 2026-03-19 18:08:55 | MaxQChange 6.092398 | QueueLength 3147 | Reward     -5992.00 | Epsilon 0.050 | EpStates  181 | NewStates    0 | TotalStates  2354
# Episode 940/1000 | StartTime 2026-03-19 18:10:05 | MaxQChange 4.846880 | QueueLength 2882 | Reward     -5445.00 | Epsilon 0.050 | EpStates  157 | NewStates    0 | TotalStates  2358
# Episode 941/1000 | StartTime 2026-03-19 18:10:09 | MaxQChange 3.843812 | QueueLength 2940 | Reward     -5255.00 | Epsilon 0.050 | EpStates  156 | NewStates    0 | TotalStates  2358
# Episode 942/1000 | StartTime 2026-03-19 18:10:13 | MaxQChange 5.413109 | QueueLength 3528 | Reward     -7392.00 | Epsilon 0.050 | EpStates  189 | NewStates    0 | TotalStates  2358
# Episode 943/1000 | StartTime 2026-03-19 18:10:17 | MaxQChange 6.672907 | QueueLength 2950 | Reward     -5131.00 | Epsilon 0.050 | EpStates  137 | NewStates    0 | TotalStates  2358
# Episode 944/1000 | StartTime 2026-03-19 18:10:22 | MaxQChange 3.940623 | QueueLength 2770 | Reward     -4731.00 | Epsilon 0.050 | EpStates  144 | NewStates    0 | TotalStates  2358
# Episode 945/1000 | StartTime 2026-03-19 18:10:26 | MaxQChange 4.956984 | QueueLength 2862 | Reward     -5245.00 | Epsilon 0.050 | EpStates  146 | NewStates    0 | TotalStates  2358
# Episode 946/1000 | StartTime 2026-03-19 18:10:30 | MaxQChange 3.729718 | QueueLength 3041 | Reward     -5153.00 | Epsilon 0.050 | EpStates  153 | NewStates    0 | TotalStates  2358
# Episode 947/1000 | StartTime 2026-03-19 18:10:34 | MaxQChange 3.653876 | QueueLength 3000 | Reward     -5096.00 | Epsilon 0.050 | EpStates  156 | NewStates    0 | TotalStates  2358
# Episode 948/1000 | StartTime 2026-03-19 18:10:38 | MaxQChange 10.654140 | QueueLength 3538 | Reward     -7556.00 | Epsilon 0.050 | EpStates  176 | NewStates    0 | TotalStates  2358
# Episode 949/1000 | StartTime 2026-03-19 18:10:42 | MaxQChange 5.013225 | QueueLength 3244 | Reward     -6019.00 | Epsilon 0.050 | EpStates  181 | NewStates    0 | TotalStates  2358
# Episode 950/1000 | StartTime 2026-03-19 18:10:46 | MaxQChange 5.535569 | QueueLength 3094 | Reward     -5908.00 | Epsilon 0.050 | EpStates  167 | NewStates    0 | TotalStates  2358
# Episode 951/1000 | StartTime 2026-03-19 18:10:50 | MaxQChange 7.782196 | QueueLength 3400 | Reward     -6558.00 | Epsilon 0.050 | EpStates  174 | NewStates    0 | TotalStates  2358
# Episode 952/1000 | StartTime 2026-03-19 18:10:54 | MaxQChange 6.302441 | QueueLength 3142 | Reward     -5965.00 | Epsilon 0.050 | EpStates  158 | NewStates    0 | TotalStates  2358
# Episode 953/1000 | StartTime 2026-03-19 18:10:58 | MaxQChange 4.373246 | QueueLength 3307 | Reward     -6205.00 | Epsilon 0.050 | EpStates  167 | NewStates    0 | TotalStates  2358
# Episode 954/1000 | StartTime 2026-03-19 18:11:02 | MaxQChange 3.267749 | QueueLength 2884 | Reward     -4771.00 | Epsilon 0.050 | EpStates  144 | NewStates    0 | TotalStates  2358
# Episode 955/1000 | StartTime 2026-03-19 18:11:07 | MaxQChange 3.588302 | QueueLength 2884 | Reward     -4794.00 | Epsilon 0.050 | EpStates  136 | NewStates    0 | TotalStates  2358
# Episode 956/1000 | StartTime 2026-03-19 18:11:11 | MaxQChange 7.843626 | QueueLength 3324 | Reward     -6879.00 | Epsilon 0.050 | EpStates  179 | NewStates    0 | TotalStates  2358
# Episode 957/1000 | StartTime 2026-03-19 18:11:15 | MaxQChange 4.526282 | QueueLength 3280 | Reward     -5593.00 | Epsilon 0.050 | EpStates  151 | NewStates    3 | TotalStates  2361
# Episode 958/1000 | StartTime 2026-03-19 18:11:19 | MaxQChange 4.658800 | QueueLength 3268 | Reward     -6357.00 | Epsilon 0.050 | EpStates  178 | NewStates    0 | TotalStates  2361
# Episode 959/1000 | StartTime 2026-03-19 18:11:23 | MaxQChange 7.137905 | QueueLength 3250 | Reward     -5959.00 | Epsilon 0.050 | EpStates  148 | NewStates    0 | TotalStates  2361
# Episode 960/1000 | StartTime 2026-03-19 18:11:27 | MaxQChange 5.857453 | QueueLength 3536 | Reward     -6919.00 | Epsilon 0.050 | EpStates  194 | NewStates    0 | TotalStates  2361
# Episode 961/1000 | StartTime 2026-03-19 18:11:31 | MaxQChange 3.970396 | QueueLength 3029 | Reward     -5491.00 | Epsilon 0.050 | EpStates  147 | NewStates    0 | TotalStates  2361
# Episode 962/1000 | StartTime 2026-03-19 18:11:36 | MaxQChange 7.335817 | QueueLength 3056 | Reward     -5539.00 | Epsilon 0.050 | EpStates  167 | NewStates    0 | TotalStates  2361
# Episode 963/1000 | StartTime 2026-03-19 18:11:40 | MaxQChange 4.037346 | QueueLength 2926 | Reward     -4518.00 | Epsilon 0.050 | EpStates  118 | NewStates    0 | TotalStates  2361
# Episode 964/1000 | StartTime 2026-03-19 18:11:44 | MaxQChange 3.833384 | QueueLength 3453 | Reward     -6919.00 | Epsilon 0.050 | EpStates  191 | NewStates    2 | TotalStates  2363
# Episode 965/1000 | StartTime 2026-03-19 18:11:48 | MaxQChange 6.745093 | QueueLength 2903 | Reward     -5520.00 | Epsilon 0.050 | EpStates  144 | NewStates    0 | TotalStates  2363
# Episode 966/1000 | StartTime 2026-03-19 18:11:52 | MaxQChange 5.644296 | QueueLength 2469 | Reward     -3903.00 | Epsilon 0.050 | EpStates  110 | NewStates    0 | TotalStates  2363
# Episode 967/1000 | StartTime 2026-03-19 18:11:56 | MaxQChange 3.582707 | QueueLength 3018 | Reward     -5402.00 | Epsilon 0.050 | EpStates  158 | NewStates    0 | TotalStates  2363
# Episode 968/1000 | StartTime 2026-03-19 18:12:01 | MaxQChange 3.597593 | QueueLength 3270 | Reward     -6288.00 | Epsilon 0.050 | EpStates  163 | NewStates    0 | TotalStates  2363
# Episode 969/1000 | StartTime 2026-03-19 18:12:05 | MaxQChange 3.611693 | QueueLength 2975 | Reward     -5523.00 | Epsilon 0.050 | EpStates  165 | NewStates    0 | TotalStates  2363
# Episode 970/1000 | StartTime 2026-03-19 18:12:09 | MaxQChange 4.699189 | QueueLength 2835 | Reward     -5043.00 | Epsilon 0.050 | EpStates  152 | NewStates    0 | TotalStates  2363
# Episode 971/1000 | StartTime 2026-03-19 18:12:13 | MaxQChange 4.702865 | QueueLength 2453 | Reward     -3874.00 | Epsilon 0.050 | EpStates  118 | NewStates    0 | TotalStates  2363
# Episode 972/1000 | StartTime 2026-03-19 18:12:18 | MaxQChange 2.998135 | QueueLength 2645 | Reward     -4245.00 | Epsilon 0.050 | EpStates  120 | NewStates    1 | TotalStates  2364
# Episode 973/1000 | StartTime 2026-03-19 18:12:22 | MaxQChange 4.578702 | QueueLength 2989 | Reward     -5490.00 | Epsilon 0.050 | EpStates  147 | NewStates    0 | TotalStates  2364
# Episode 974/1000 | StartTime 2026-03-19 18:12:26 | MaxQChange 4.046733 | QueueLength 3229 | Reward     -6297.00 | Epsilon 0.050 | EpStates  172 | NewStates    0 | TotalStates  2364
# Episode 975/1000 | StartTime 2026-03-19 18:12:30 | MaxQChange 6.423409 | QueueLength 2868 | Reward     -5086.00 | Epsilon 0.050 | EpStates  150 | NewStates    0 | TotalStates  2364
# Episode 976/1000 | StartTime 2026-03-19 18:12:34 | MaxQChange 7.265065 | QueueLength 3235 | Reward     -6139.00 | Epsilon 0.050 | EpStates  154 | NewStates    0 | TotalStates  2364
# Episode 977/1000 | StartTime 2026-03-19 18:12:38 | MaxQChange 2.818119 | QueueLength 2668 | Reward     -4184.00 | Epsilon 0.050 | EpStates  115 | NewStates    0 | TotalStates  2364
# Episode 978/1000 | StartTime 2026-03-19 18:12:43 | MaxQChange 2.571716 | QueueLength 2959 | Reward     -5005.00 | Epsilon 0.050 | EpStates  143 | NewStates    0 | TotalStates  2364
# Episode 979/1000 | StartTime 2026-03-19 18:12:47 | MaxQChange 2.963603 | QueueLength 2970 | Reward     -5150.00 | Epsilon 0.050 | EpStates  157 | NewStates    0 | TotalStates  2364
# Episode 980/1000 | StartTime 2026-03-19 18:12:51 | MaxQChange 4.961462 | QueueLength 3278 | Reward     -6086.00 | Epsilon 0.050 | EpStates  160 | NewStates    0 | TotalStates  2364
# Episode 981/1000 | StartTime 2026-03-19 18:12:55 | MaxQChange 7.094685 | QueueLength 3232 | Reward     -6338.00 | Epsilon 0.050 | EpStates  157 | NewStates    1 | TotalStates  2365
# Episode 982/1000 | StartTime 2026-03-19 18:12:59 | MaxQChange 3.729176 | QueueLength 3163 | Reward     -5582.00 | Epsilon 0.050 | EpStates  138 | NewStates    0 | TotalStates  2365
# Episode 983/1000 | StartTime 2026-03-19 18:13:03 | MaxQChange 3.524240 | QueueLength 3167 | Reward     -5614.00 | Epsilon 0.050 | EpStates  147 | NewStates    0 | TotalStates  2365
# Episode 984/1000 | StartTime 2026-03-19 18:13:07 | MaxQChange 5.105255 | QueueLength 2715 | Reward     -4769.00 | Epsilon 0.050 | EpStates  139 | NewStates    0 | TotalStates  2365
# Episode 985/1000 | StartTime 2026-03-19 18:13:12 | MaxQChange 3.385928 | QueueLength 3041 | Reward     -5548.00 | Epsilon 0.050 | EpStates  141 | NewStates    0 | TotalStates  2365
# Episode 986/1000 | StartTime 2026-03-19 18:13:16 | MaxQChange 6.955955 | QueueLength 3533 | Reward     -6914.00 | Epsilon 0.050 | EpStates  181 | NewStates    0 | TotalStates  2365
# Episode 987/1000 | StartTime 2026-03-19 18:13:20 | MaxQChange 8.161884 | QueueLength 3452 | Reward     -7023.00 | Epsilon 0.050 | EpStates  172 | NewStates    0 | TotalStates  2365
# Episode 988/1000 | StartTime 2026-03-19 18:13:24 | MaxQChange 4.854615 | QueueLength 2983 | Reward     -4905.00 | Epsilon 0.050 | EpStates  140 | NewStates    0 | TotalStates  2365
# Episode 989/1000 | StartTime 2026-03-19 18:13:28 | MaxQChange 3.596247 | QueueLength 2635 | Reward     -3897.00 | Epsilon 0.050 | EpStates  110 | NewStates    0 | TotalStates  2365
# Episode 990/1000 | StartTime 2026-03-19 18:13:33 | MaxQChange 8.222709 | QueueLength 3598 | Reward     -7248.00 | Epsilon 0.050 | EpStates  175 | NewStates    0 | TotalStates  2365
# Episode 991/1000 | StartTime 2026-03-19 18:13:37 | MaxQChange 4.552329 | QueueLength 3349 | Reward     -6879.00 | Epsilon 0.050 | EpStates  166 | NewStates    1 | TotalStates  2366
# Episode 992/1000 | StartTime 2026-03-19 18:13:41 | MaxQChange 7.519113 | QueueLength 2959 | Reward     -5078.00 | Epsilon 0.050 | EpStates  124 | NewStates    0 | TotalStates  2366
# Episode 993/1000 | StartTime 2026-03-19 18:13:45 | MaxQChange 2.302649 | QueueLength 2783 | Reward     -4320.00 | Epsilon 0.050 | EpStates  131 | NewStates    0 | TotalStates  2366
# Episode 994/1000 | StartTime 2026-03-19 18:13:49 | MaxQChange 3.906503 | QueueLength 2868 | Reward     -4742.00 | Epsilon 0.050 | EpStates  130 | NewStates    0 | TotalStates  2366
# Episode 995/1000 | StartTime 2026-03-19 18:13:53 | MaxQChange 4.958411 | QueueLength 2970 | Reward     -4801.00 | Epsilon 0.050 | EpStates  127 | NewStates    0 | TotalStates  2366
# Episode 996/1000 | StartTime 2026-03-19 18:13:57 | MaxQChange 4.691914 | QueueLength 2871 | Reward     -4854.00 | Epsilon 0.050 | EpStates  137 | NewStates    0 | TotalStates  2366
# Episode 997/1000 | StartTime 2026-03-19 18:14:02 | MaxQChange 5.804643 | QueueLength 3462 | Reward     -6766.00 | Epsilon 0.050 | EpStates  173 | NewStates    0 | TotalStates  2366
# Episode 998/1000 | StartTime 2026-03-19 18:14:06 | MaxQChange 3.806557 | QueueLength 3110 | Reward     -5510.00 | Epsilon 0.050 | EpStates  164 | NewStates    0 | TotalStates  2366
# Episode 999/1000 | StartTime 2026-03-19 18:14:10 | MaxQChange 11.255131 | QueueLength 4370 | Reward    -11252.00 | Epsilon 0.050 | EpStates  229 | NewStates    0 | TotalStates  2366
# Episode 1000/1000 | StartTime 2026-03-19 18:14:14 | MaxQChange 5.331863 | QueueLength 3049 | Reward     -5595.00 | Epsilon 0.050 | EpStates  154 | NewStates    0 | TotalStates  2366
#
# Training finished
# Total learned states: 2366
